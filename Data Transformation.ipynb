# %% [markdown]
# # Teknik Imputasi

# %% [markdown]
# ## Thojing Dea Pallaqi

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
#Import data
df = pd.read_csv('Data/melb_data.csv', sep= ';')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#        Date Distance    Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0  03/12/16    02.05  3067.00.00  ...       1.0  1.0  202.00.00          NaN
# 1  04/02/16    02.05  3067.00.00  ...       1.0  0.0  156.00.00     79.00.00
# 2  04/03/17    02.05  3067.00.00  ...       2.0  0.0  134.00.00    150.00.00
# 3  04/03/17    02.05  3067.00.00  ...       2.0  1.0   94.00.00          NaN
# 4  04/06/16    02.05  3067.00.00  ...       1.0  2.0  120.00.00    142.00.00
#
#     YearBuilt CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
#Info data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  object
#  9   Postcode       13580 non-null  object
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  object
#  14  BuildingArea   7130 non-null   object
#  15  YearBuilt      8205 non-null   object
#  16  CouncilArea    12211 non-null  object
# ...

# %%
#Mengambil 1500 baris pertama
df = df[:1500]
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#        Date Distance    Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0  03/12/16    02.05  3067.00.00  ...       1.0  1.0  202.00.00          NaN
# 1  04/02/16    02.05  3067.00.00  ...       1.0  0.0  156.00.00     79.00.00
# 2  04/03/17    02.05  3067.00.00  ...       2.0  0.0  134.00.00    150.00.00
# 3  04/03/17    02.05  3067.00.00  ...       2.0  1.0   94.00.00          NaN
# 4  04/06/16    02.05  3067.00.00  ...       1.0  2.0  120.00.00    142.00.00
#
#     YearBuilt CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
#Info data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         1500 non-null   object
#  1   Address        1500 non-null   object
#  2   Rooms          1500 non-null   int64
#  3   Type           1500 non-null   object
#  4   Price          1500 non-null   float64
#  5   Method         1500 non-null   object
#  6   SellerG        1500 non-null   object
#  7   Date           1500 non-null   object
#  8   Distance       1500 non-null   object
#  9   Postcode       1500 non-null   object
#  10  Bedroom2       1500 non-null   float64
#  11  Bathroom       1500 non-null   float64
#  12  Car            1500 non-null   float64
#  13  Landsize       1500 non-null   object
#  14  BuildingArea   847 non-null    object
#  15  YearBuilt      963 non-null    object
#  16  CouncilArea    1500 non-null   object
# ...

# %%
#Jumlah data kosong
df.isna().sum()
# Out:
# Suburb             0
# Address            0
# Rooms              0
# Type               0
# Price              0
# Method             0
# SellerG            0
# Date               0
# Distance           0
# Postcode           0
# Bedroom2           0
# Bathroom           0
# Car                0
# Landsize           0
# BuildingArea     653
# YearBuilt        537
# CouncilArea        0
# Lattitude          0
# Longtitude         0
# Regionname         0
# Propertycount      0
# dtype: int64

# %%
#Tipe data
df.dtypes.value_counts()
# Out:
# object     16
# float64     4
# int64       1
# dtype: int64

# %%
#Merapikan baris Date
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date Distance    Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0 2016-03-12    02.05  3067.00.00  ...       1.0  1.0  202.00.00          NaN
# 1 2016-04-02    02.05  3067.00.00  ...       1.0  0.0  156.00.00     79.00.00
# 2 2017-04-03    02.05  3067.00.00  ...       2.0  0.0  134.00.00    150.00.00
# 3 2017-04-03    02.05  3067.00.00  ...       2.0  1.0   94.00.00          NaN
# 4 2016-04-06    02.05  3067.00.00  ...       1.0  2.0  120.00.00    142.00.00
#
#     YearBuilt CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
regex = r'^(\d{4})'

# %%
#Merapikan baris Postcode
extr = df['Postcode'].str.extract(r'^(\d{4})', expand=False)
extr.head()
# Out:
# 0    3067
# 1    3067
# 2    3067
# 3    3067
# 4    3067
# Name: Postcode, dtype: object

# %%
df['Postcode'] = pd.to_numeric(extr)
df['Postcode'].dtype
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date Distance  Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0 2016-03-12    02.05      3067  ...       1.0  1.0  202.00.00          NaN
# 1 2016-04-02    02.05      3067  ...       1.0  0.0  156.00.00     79.00.00
# 2 2017-04-03    02.05      3067  ...       2.0  0.0  134.00.00    150.00.00
# 3 2017-04-03    02.05      3067  ...       2.0  1.0   94.00.00          NaN
# 4 2016-04-06    02.05      3067  ...       1.0  2.0  120.00.00    142.00.00
#
#     YearBuilt CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
#Merapikan baris Price
df['Price'] = df['Price'].astype(int)
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date Distance  Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0 2016-03-12    02.05      3067  ...       1.0  1.0  202.00.00          NaN
# 1 2016-04-02    02.05      3067  ...       1.0  0.0  156.00.00     79.00.00
# 2 2017-04-03    02.05      3067  ...       2.0  0.0  134.00.00    150.00.00
# 3 2017-04-03    02.05      3067  ...       2.0  1.0   94.00.00          NaN
# 4 2016-04-06    02.05      3067  ...       1.0  2.0  120.00.00    142.00.00
#
#     YearBuilt CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
#Merapikan baris Bathroo
df['Bathroom'] = df['Bathroom'].astype(int)
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date Distance  Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0 2016-03-12    02.05      3067  ...         1  1.0  202.00.00          NaN
# 1 2016-04-02    02.05      3067  ...         1  0.0  156.00.00     79.00.00
# 2 2017-04-03    02.05      3067  ...         2  0.0  134.00.00    150.00.00
# 3 2017-04-03    02.05      3067  ...         2  1.0   94.00.00          NaN
# 4 2016-04-06    02.05      3067  ...         1  2.0  120.00.00    142.00.00
#
#     YearBuilt CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
#Merapikan baris Bedroom2
df['Bedroom2'] = df['Bedroom2'].astype(int)
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date Distance  Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0 2016-03-12    02.05      3067  ...         1  1.0  202.00.00          NaN
# 1 2016-04-02    02.05      3067  ...         1  0.0  156.00.00     79.00.00
# 2 2017-04-03    02.05      3067  ...         2  0.0  134.00.00    150.00.00
# 3 2017-04-03    02.05      3067  ...         2  1.0   94.00.00          NaN
# 4 2016-04-06    02.05      3067  ...         1  2.0  120.00.00    142.00.00
#
#     YearBuilt CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
#Merapikan baris Car
df['Car'] = df['Car'].astype(int)
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date Distance  Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0 2016-03-12    02.05      3067  ...         1    1  202.00.00          NaN
# 1 2016-04-02    02.05      3067  ...         1    0  156.00.00     79.00.00
# 2 2017-04-03    02.05      3067  ...         2    0  134.00.00    150.00.00
# 3 2017-04-03    02.05      3067  ...         2    1   94.00.00          NaN
# 4 2016-04-06    02.05      3067  ...         1    2  120.00.00    142.00.00
#
#     YearBuilt CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
#Merapikan baris YearBuilt
extr = df['YearBuilt'].astype(str).str.extract(r'^(\d{4})', expand=False)
extr.head()
# Out:
# 0     NaN
# 1    1900
# 2    1900
# 3     NaN
# 4    2014
# Name: YearBuilt, dtype: object

# %%
df['YearBuilt'] = pd.to_numeric(extr)
df['YearBuilt'].dtype
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date Distance  Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0 2016-03-12    02.05      3067  ...         1    1  202.00.00          NaN
# 1 2016-04-02    02.05      3067  ...         1    0  156.00.00     79.00.00
# 2 2017-04-03    02.05      3067  ...         2    0  134.00.00    150.00.00
# 3 2017-04-03    02.05      3067  ...         2    1   94.00.00          NaN
# 4 2016-04-06    02.05      3067  ...         1    2  120.00.00    142.00.00
#
#   YearBuilt  CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
#Merapikan baris Propertycount
extr = df['Propertycount'].str.extract(r'^(\d{4})', expand=False)
extr.head()
# Out:
# 0    4019
# 1    4019
# 2    4019
# 3    4019
# 4    4019
# Name: Propertycount, dtype: object

# %%
df['Propertycount'] = pd.to_numeric(extr)
df['Propertycount'].dtype
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date Distance  Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0 2016-03-12    02.05      3067  ...         1    1  202.00.00          NaN
# 1 2016-04-02    02.05      3067  ...         1    0  156.00.00     79.00.00
# 2 2017-04-03    02.05      3067  ...         2    0  134.00.00    150.00.00
# 3 2017-04-03    02.05      3067  ...         2    1   94.00.00          NaN
# 4 2016-04-06    02.05      3067  ...         1    2  120.00.00    142.00.00
#
#   YearBuilt  CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
#Menambahkan data yang kosong pada variabel BuildingArea & YearBuilt dengan Frequent Category
imp = SimpleImputer(strategy='most_frequent')

# %%
df = imp.fit_transform(df)

# %%
print(df)
# Out:
# [['Abbotsford' '85 Turner St' 2 ... '1.449.984' 'Northern Metropolitan'
#   4019]
#  ['Abbotsford' '25 Bloomburg St' 2 ... '1.449.934'
#   'Northern Metropolitan' 4019]
#  ['Abbotsford' '5 Charles St' 3 ... '1.449.944' 'Northern Metropolitan'
#   4019]
#  ...
#  ['Bulleen' '4 Graeme Ct' 4 ... '145.088' 'Eastern Metropolitan' 4480]
#  ['Bulleen' '19 Barak St' 4 ... '1.450.863' 'Eastern Metropolitan' 4480]
#  ['Bulleen' '13 Birrarrung Ct' 4 ... '1.450.913' 'Eastern Metropolitan'
#   4480]]

# %%
df = pd.DataFrame(df,
                    columns=['Suburb','Address','Rooms','Type','Price','Method',
                            'SellerG','Date','Distance','Postcode','Bedroom2','Bathroom',
                            'Car','Landsize','BuildingArea','YearBuilt','CouncilArea',
                            'Lattitude','Longtitude','Regionname','Propertycount'])

# %%
df.head()
# Out:
#        Suburb           Address Rooms Type    Price Method SellerG       Date  \
# 0  Abbotsford      85 Turner St     2    h  1480000      S  Biggin 2016-03-12
# 1  Abbotsford   25 Bloomburg St     2    h  1035000      S  Biggin 2016-04-02
# 2  Abbotsford      5 Charles St     3    h  1465000     SP  Biggin 2017-04-03
# 3  Abbotsford  40 Federation La     3    h   850000     PI  Biggin 2017-04-03
# 4  Abbotsford       55a Park St     4    h  1600000     VB  Nelson 2016-04-06
#
#   Distance Postcode  ... Bathroom Car   Landsize BuildingArea YearBuilt  \
# 0    02.05     3067  ...        1   1  202.00.00    120.00.00    1950.0
# 1    02.05     3067  ...        1   0  156.00.00     79.00.00    1900.0
# 2    02.05     3067  ...        2   0  134.00.00    150.00.00    1900.0
# 3    02.05     3067  ...        2   1   94.00.00    120.00.00    1950.0
# 4    02.05     3067  ...        1   2  120.00.00    142.00.00    2014.0
#
# ...

# %%
df['YearBuilt'] = df['YearBuilt'].astype(int)

# %%
df['Rooms'] = df['Rooms'].astype(int)

# %%
df['Price'] = df['Price'].astype(int)

# %%
df['Distance'] = pd.to_numeric(df['Distance'])

# %%
df['Postcode'] = df['Postcode'].astype(int)

# %%
df['Bedroom2'] = df['Bedroom2'].astype(int)

# %%
df['Bathroom'] = df['Bathroom'].astype(int)

# %%
df['Car'] = df['Car'].astype(int)

# %%
df['Propertycount'] = df['Propertycount'].astype(int)

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car   Landsize BuildingArea  \
# 0 2016-03-12      2.05      3067  ...         1    1  202.00.00    120.00.00
# 1 2016-04-02      2.05      3067  ...         1    0  156.00.00     79.00.00
# 2 2017-04-03      2.05      3067  ...         2    0  134.00.00    150.00.00
# 3 2017-04-03      2.05      3067  ...         2    1   94.00.00    120.00.00
# 4 2016-04-06      2.05      3067  ...         1    2  120.00.00    142.00.00
#
#   YearBuilt  CouncilArea Lattitude Longtitude             Regionname  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         1500 non-null   object
#  1   Address        1500 non-null   object
#  2   Rooms          1500 non-null   int32
#  3   Type           1500 non-null   object
#  4   Price          1500 non-null   int32
#  5   Method         1500 non-null   object
#  6   SellerG        1500 non-null   object
#  7   Date           1500 non-null   datetime64[ns]
#  8   Distance       1500 non-null   float64
#  9   Postcode       1500 non-null   int32
#  10  Bedroom2       1500 non-null   int32
#  11  Bathroom       1500 non-null   int32
#  12  Car            1500 non-null   int32
#  13  Landsize       1500 non-null   object
#  14  BuildingArea   1500 non-null   object
#  15  YearBuilt      1500 non-null   int32
#  16  CouncilArea    1500 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  1500.000000  1.500000e+03  1500.000000  1500.000000  1500.000000
# mean      3.049333  1.249755e+06     9.279840  3115.108000     3.010000
# std       0.969979  6.954665e+05     3.336257    62.366134     0.968775
# min       1.000000  2.400000e+05     2.050000  3018.000000     0.000000
# 25%       2.000000  7.700000e+05     6.030000  3056.000000     2.000000
# 50%       3.000000  1.100000e+06    10.070000  3105.000000     3.000000
# 75%       4.000000  1.537750e+06    13.000000  3165.000000     4.000000
# max       8.000000  5.525000e+06    13.090000  3206.000000     9.000000
#
#           Bathroom          Car    YearBuilt  Propertycount
# count  1500.000000  1500.000000  1500.000000    1500.000000
# mean      1.625333     1.676000  1957.245333    4185.246667
# std       0.777192     0.958281    29.326413    2391.438925
# min       0.000000     0.000000  1880.000000    1057.000000
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Call StandardScaler
# ----> 2 scaler = StandardScaler()
#       3 # Standardization of dataset values
#       4 scaler.fit(X)
#
# NameError: name 'StandardScaler' is not defined
