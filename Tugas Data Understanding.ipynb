# %% [markdown]
# # Tugas Data Understanding

# %% [markdown]
# ### Thojing Dea Pallaqi

# %%
import json
import pandas as pd
import requests
import kaggle
import tqdm

# %% [markdown]
# ## KAGGLE

# %% [markdown]
# ### Kaggle 1

# %%
# !kaggle datasets list -s "The Movies Dataset"

# %%
# !kaggle datasets download georgescutelnicu/top-100-popular-movies-from-2003-to-2022-imdb
# Out:
# ...
#   0%|          | 0.00/132k [00:00<?, ?B/s]
# 100%|##########| 132k/132k [00:00<00:00, 341kB/s]
# 100%|##########| 132k/132k [00:00<00:00, 341kB/s]

# %%
movies= pd.read_csv('Data/Movies.csv')
movies.head()
# Out:
#                             Title  Rating  Year     Month Certificate Runtime  \
# 0        Avatar: The Way of Water     7.8  2022  December       PG-13     192
# 1  Guillermo del Toro's Pinocchio     7.6  2022  December          PG     117
# 2                    Bullet Train     7.3  2022    August           R     127
# 3       The Banshees of Inisherin     7.8  2022  November           R     114
# 4                           M3gan     6.4  2022  December       PG-13     102
#
#                             Directors  \
# 0                       James Cameron
# 1  Guillermo del Toro, Mark Gustafson
# 2                        David Leitch
# 3                     Martin McDonagh
# 4                    Gerard Johnstone
#
#                                                Stars  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1  Ewan McGregor, David Bradley, Gregory Mann, Bu...
# 2  Brad Pitt, Joey King, Aaron Taylor Johnson, Br...
# ...

# %% [markdown]
# ### Kaggle 2

# %%
# !kaggle datasets download nagrajdesai/latest-10000-movies-dataset-from-tmdb
# Out:
# ...
#   0%|          | 0.00/1.34M [00:00<?, ?B/s]
#  75%|#######4  | 1.00M/1.34M [00:01<00:00, 541kB/s]
# 100%|##########| 1.34M/1.34M [00:02<00:00, 691kB/s]
# ...
#   0%|          | 0.00/228M [00:00<?, ?B/s]
#   0%|          | 1.00M/228M [00:02<07:50, 506kB/s]
#   1%|          | 2.00M/228M [00:03<06:40, 591kB/s]
#   1%|1         | 3.00M/228M [00:05<06:29, 605kB/s]
#   2%|1         | 4.00M/228M [00:06<05:42, 685kB/s]
#   2%|2         | 5.00M/228M [00:07<05:09, 755kB/s]
#   3%|2         | 6.00M/228M [00:08<04:33, 851kB/s]
#   3%|3         | 7.00M/228M [00:09<04:05, 945kB/s]
#   4%|3         | 8.00M/228M [00:10<03:47, 1.02MB/s]
#   4%|3         | 9.00M/228M [00:11<03:25, 1.12MB/s]
#   4%|4         | 10.0M/228M [00:11<03:10, 1.20MB/s]
#   5%|4         | 11.0M/228M [00:12<02:50, 1.33MB/s]
#   5%|5         | 12.0M/228M [00:12<02:31, 1.50MB/s]
#   6%|5         | 13.0M/228M [00:13<02:18, 1.63MB/s]
#   6%|6         | 14.0M/228M [00:13<02:08, 1.74MB/s]
# ...

# %%
from zipfile import ZipFile
dataset = 'Data\latest-10000-movies-dataset-from-tmdb.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
movies = pd.read_csv('Data/Movies_dataset.csv')
movies.head()
# Out:
#    index                                title original_language release_date  \
# 0      0  Spider-Man: Across the Spider-Verse                en   31-05-2023
# 1      1     Transformers: Rise of the Beasts                en   06-06-2023
# 2      2                            The Flash                en   13-06-2023
# 3      3                     No Hard Feelings                en   15-06-2023
# 4      4                               Barbie                en   19-07-2023
#
#    popularity  vote_average  vote_count  \
# 0    3368.627           8.5        3386
# 1    2160.316           7.5        2747
# 2    2108.713           7.0        2305
# 3    1978.358           7.1         562
# 4    1976.513           7.5        3013
#
#                                             overview
# 0  After reuniting with Gwen Stacy, Brooklyn’s fu...
# 1  When a new threat capable of destroying the en...
# 2  When his attempt to save his family inadverten...
# ...

# %%
movies.drop(columns='index', inplace=True)
movies.head()
# Out:
#                                  title original_language release_date  \
# 0  Spider-Man: Across the Spider-Verse                en   31-05-2023
# 1     Transformers: Rise of the Beasts                en   06-06-2023
# 2                            The Flash                en   13-06-2023
# 3                     No Hard Feelings                en   15-06-2023
# 4                               Barbie                en   19-07-2023
#
#    popularity  vote_average  vote_count  \
# 0    3368.627           8.5        3386
# 1    2160.316           7.5        2747
# 2    2108.713           7.0        2305
# 3    1978.358           7.1         562
# 4    1976.513           7.5        3013
#
#                                             overview
# 0  After reuniting with Gwen Stacy, Brooklyn’s fu...
# 1  When a new threat capable of destroying the en...
# 2  When his attempt to save his family inadverten...
# 3  On the brink of losing her childhood home, Mad...
# ...

# %% [markdown]
# ### Kaggle 3

# %%
# !kaggle datasets download kaggle/sf-salaries
# Out:
# ...
#   0%|          | 0.00/11.5M [00:00<?, ?B/s]
#   9%|8         | 1.00M/11.5M [00:01<00:14, 770kB/s]
#  17%|#7        | 2.00M/11.5M [00:02<00:11, 859kB/s]
#  26%|##6       | 3.00M/11.5M [00:03<00:09, 891kB/s]
#  35%|###4      | 4.00M/11.5M [00:04<00:08, 889kB/s]
#  44%|####3     | 5.00M/11.5M [00:05<00:07, 911kB/s]
#  52%|#####2    | 6.00M/11.5M [00:06<00:05, 971kB/s]
#  61%|######    | 7.00M/11.5M [00:07<00:04, 997kB/s]
#  70%|######9   | 8.00M/11.5M [00:08<00:03, 1.00MB/s]
#  78%|#######8  | 9.00M/11.5M [00:09<00:02, 1.05MB/s]
#  87%|########7 | 10.0M/11.5M [00:10<00:01, 1.11MB/s]
#  96%|#########5| 11.0M/11.5M [00:11<00:00, 1.13MB/s]
# 100%|##########| 11.5M/11.5M [00:11<00:00, 1.14MB/s]
# 100%|##########| 11.5M/11.5M [00:11<00:00, 1.01MB/s]

# %%
from zipfile import ZipFile
dataset = 'Data\sf-salaries.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted
# ...
#   0%|          | 0.00/554M [00:00<?, ?B/s]
#   0%|          | 1.00M/554M [00:01<14:28, 668kB/s]
#   0%|          | 2.00M/554M [00:02<12:00, 804kB/s]
#   1%|          | 3.00M/554M [00:03<10:59, 877kB/s]
#   1%|          | 4.00M/554M [00:04<10:41, 899kB/s]
#   1%|          | 5.00M/554M [00:05<10:18, 932kB/s]
#   1%|1         | 6.00M/554M [00:06<09:51, 973kB/s]
#   1%|1         | 7.00M/554M [00:07<08:45, 1.09MB/s]
#   1%|1         | 8.00M/554M [00:08<07:42, 1.24MB/s]
#   2%|1         | 9.00M/554M [00:08<06:56, 1.37MB/s]
#   2%|1         | 10.0M/554M [00:09<06:23, 1.49MB/s]
#   2%|1         | 11.0M/554M [00:09<05:58, 1.59MB/s]
#   2%|2         | 12.0M/554M [00:10<05:19, 1.78MB/s]
#   2%|2         | 13.0M/554M [00:10<04:56, 1.92MB/s]
#   3%|2         | 14.0M/554M [00:11<04:34, 2.06MB/s]
#   3%|2         | 15.0M/554M [00:11<04:21, 2.16MB/s]
#   3%|2         | 16.0M/554M [00:12<04:06, 2.29MB/s]
#   3%|3         | 17.0M/554M [00:12<04:20, 2.16MB/s]
# ...

# %%
salary = pd.read_csv('Data/Salaries.csv')
salary.head()
# Out:
# C:\Users\Asani\AppData\Local\Temp\ipykernel_1740\4230713647.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   salary = pd.read_csv('Data/Salaries.csv')
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# ...

# %% [markdown]
# ### Kaggle 4

# %%
# !kaggle datasets download mssmartypants/paris-housing-price-prediction
# Out:
# ...
#   0%|          | 0.00/269k [00:00<?, ?B/s]
# 100%|##########| 269k/269k [00:00<00:00, 492kB/s]
# 100%|##########| 269k/269k [00:00<00:00, 492kB/s]

# %%
from zipfile import ZipFile
dataset = 'Data\paris-housing-price-prediction.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
house = pd.read_csv('Data/ParisHousing.csv')
house.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %% [markdown]
# ### Kaggle 5

# %%
# !kaggle datasets download aaronschlegel/petfinder-animal-shelters-database
# Out:
# ...
#   0%|          | 0.00/473k [00:00<?, ?B/s]
# 100%|##########| 473k/473k [00:00<00:00, 521kB/s]
# 100%|##########| 473k/473k [00:00<00:00, 521kB/s]

# %%
from zipfile import ZipFile
dataset = 'Data\petfinder-animal-shelters-database.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
ps = pd.read_csv ('Data/petfinder_shelters.csv')
ps.head()
# Out:
#                 address1      address2      city country  \
# 0         195 State Road           NaN   Kittery      US
# 1          94 Grove Road           NaN       Rye      US
# 2                    NaN           NaN       Rye      US
# 3  104 Portsmouth Avenue  P.O. Box 196  Stratham      US
# 4                    NaN           NaN      York      US
#
#                                   email     id  latitude  longitude  \
# 0                AdoptionsKAH@gmail.com  ME118   43.0899   -70.7415
# 1                    lgrovefarm@aol.com   NH81   42.9885   -70.8282
# 2            Rescue@NNEwestierescue.org  NH140   42.9885   -70.8282
# 3                       info@nhspca.org   NH31   43.0028   -70.9212
# 4  thegratefuldoganimalrescue@gmail.com  ME158   43.1502   -70.6281
#
#                                                 name           phone state  \
# 0  Kittery Animal Hospital and Creature Comforts LLC  (207) 439-4158    ME
# ...

# %% [markdown]
# ### UCI MACHINE LEARNING REPOSITORY

# %%
#UCI Machine Learning Repository
# !pip install ucimlrepo
# Out:
# ...
#   Obtaining dependency information for ucimlrepo from https://files.pythonhosted.org/packages/85/8b/aab8a1c1344af158feb0b7f13d15ae184bc1e93625cea98d9c783b2e29d4/ucimlrepo-0.0.2-py3-none-any.whl.metadata
# ...

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
mushroom = fetch_ucirepo(id=73) 
  
# data (as pandas dataframes) 
X = mushroom.data.features 
y = mushroom.data.targets 

# variable information 
print(mushroom.variables)
# Out:
#                         name     role         type demographic  \
# 0                  poisonous   Target  Categorical        None
# 1                  cap-shape  Feature  Categorical        None
# 2                cap-surface  Feature  Categorical        None
# 3                  cap-color  Feature       Binary        None
# 4                    bruises  Feature  Categorical        None
# 5                       odor  Feature  Categorical        None
# 6            gill-attachment  Feature  Categorical        None
# 7               gill-spacing  Feature  Categorical        None
# 8                  gill-size  Feature  Categorical        None
# 9                 gill-color  Feature  Categorical        None
# 10               stalk-shape  Feature  Categorical        None
# 11                stalk-root  Feature  Categorical        None
# 12  stalk-surface-above-ring  Feature  Categorical        None
# 13  stalk-surface-below-ring  Feature  Categorical        None
# ...

# %% [markdown]
# ### SUMBER LAINNYA

# %%
#FruitAPI
response = requests.get("https://fruityvice.com/api/fruit/all")
a = response.text
df = pd.read_json(a)
df.head()
# Out:
# C:\Users\Asani\AppData\Local\Temp\ipykernel_3160\1159459674.py:4: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(a)
#          name  id      family         order      genus  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria
# 2      Banana   1    Musaceae  Zingiberales       Musa
# 3      Tomato   5  Solanaceae     Solanales    Solanum
# 4        Pear   4    Rosaceae       Rosales      Pyrus
#
#                                           nutritions
# 0  {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2  {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3  {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4  {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...
