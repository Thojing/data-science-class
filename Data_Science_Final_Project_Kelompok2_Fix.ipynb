# %% [markdown]
# # Klasifikasi Potensi Energi Terbarukan

# %% [markdown]
# Anggota Kelompok
# 1. Moh Syahrul H
# 2. Nurindarlina
# 3. Rihan Adlillah
# 4. Thia Marliana
# 5. Thojing Dea Pallaqi

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Import library yang akan digunakan pada Exploratory Data Analysis
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#menampilkan data
df = pd.read_csv('Data/global-data-on-sustainable-energy (1).csv')
df.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
#menampilkan kolom pada datasheet
df.columns
# Out:
# Index(['Entity', 'Year', 'Access to electricity (% of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Financial flows to developing countries (US $)',
#        'Renewable energy share in the total final energy consumption (%)',
#        'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)',
#        'Electricity from renewables (TWh)',
#        'Low-carbon electricity (% electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'Value_co2_emissions_kt_by_country',
#        'Renewables (% equivalent primary energy)', 'gdp_growth',
#        'gdp_per_capita', 'Density', 'Land Area(Km2)', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
#menampilkan info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 21 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            3649 non-null   object
#  1   Year                                                              3649 non-null   int64
#  2   Access to electricity (% of population)                           3639 non-null   float64
#  3   Access to clean fuels for cooking                                 3480 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita              2718 non-null   float64
#  5   Financial flows to developing countries (US $)                    1560 non-null   float64
#  6   Renewable energy share in the total final energy consumption (%)  3455 non-null   float64
# ...

# %%
#menampilkan variabel statistik dari datasheet
df.describe()
# Out:
#               Year  Access to electricity (% of population)  \
# count  3649.000000                              3639.000000
# mean   2010.038367                                78.933702
# std       6.054228                                30.275541
# min    2000.000000                                 1.252269
# 25%    2005.000000                                59.800890
# 50%    2010.000000                                98.361570
# 75%    2015.000000                               100.000000
# max    2020.000000                               100.000000
#
#        Access to clean fuels for cooking  \
# count                        3480.000000
# mean                           63.255287
# std                            39.043658
# min                             0.000000
# 25%                            23.175000
# 50%                            83.150000
# 75%                           100.000000
# max                           100.000000
#
# ...

# %%
#menampilakan dimensi datasheet ( row data, columns)
df.shape
# Out:
# (3649, 21)

# %% [markdown]
# Issue : Renewable energy potential assessment
#
# Variabel X :
# 1. Electricity from fossil fuels (TWh): Electricity generated from fossil fuels (coal, oil, gas) in terawatt-hours.
# 2. Electricity from renewables (TWh): Electricity generated from renewable sources (hydro, solar, wind, etc.) in terawatt-hours.
# 3. GDP growth (annual %): Annual GDP growth rate based on constant local currency
# 4. Access to electricity (% of population): The percentage of population with access to electricity.
# 5. Access to clean fuels for cooking (% of population): The percentage of the population with primary reliance on clean fuels
# 6. Renewable-electricity-generating-capacity-per-capita: Installed Renewable energy capacity per person
# 7. Primary energy consumption per capita (kWh/person): Energy consumption per person in kilowatt-hours.
# 8. Density
#
#
# Variable : Y
# 1. Entity: The name of the country or region for which the data is reported.

# %%
#membuat daftar kolom yan akan dihapus 
to_drop =['Year','Financial flows to developing countries (US $)',
          'Renewable energy share in the total final energy consumption (%)',
          'Electricity from nuclear (TWh)',
          'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
          'Value_co2_emissions_kt_by_country',
          'Renewables (% equivalent primary energy)',
          'Low-carbon electricity (% electricity)',
          'gdp_per_capita','Land Area(Km2)', 'Latitude','Longitude']

# %%
#menghapus kolom 
df.drop(columns=to_drop, inplace=True)

# %%
df.columns
# Out:
# Index(['Entity', 'Access to electricity (% of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Electricity from fossil fuels (TWh)',
#        'Electricity from renewables (TWh)',
#        'Primary energy consumption per capita (kWh/person)', 'gdp_growth',
#        'Density'],
#       dtype='object')

# %%
#membuat daftar nama kolom baru
New_name = {'Entity': 'Wilayah', 
            'Access to electricity (% of population)' : 'Akses Jaringan Listrik (%)',
            'Access to clean fuels for cooking' : 'Akses Bahan Bakar Bersih',
            'Renewable-electricity-generating-capacity-per-capita' : 'Kapasitas Pembangkit Listrik Terbarukan per Kapita',
            'Electricity from fossil fuels (TWh)':'Listrik dari Bahan Bakar Fosil (TWh)',
            'Electricity from renewables (TWh)':'Listrik dari Energi Terbarukan (TWh)',
            'Density' : 'Kepadatan_Penduduk', 
            'Primary energy consumption per capita (kWh/person)' : 'Konsumsi Energi Primer per Kapita (kWh/orang)',
            'gdp_growth':'Pertumbuhan PDB (% Tahun)'}

# %%
#rename kolom
df.rename(columns=New_name, inplace = True)

# %%
df.columns
# Out:
# Index(['Wilayah', 'Akses Jaringan Listrik (%)', 'Akses Bahan Bakar Bersih',
#        'Kapasitas Pembangkit Listrik Terbarukan per Kapita',
#        'Listrik dari Bahan Bakar Fosil (TWh)',
#        'Listrik dari Energi Terbarukan (TWh)',
#        'Konsumsi Energi Primer per Kapita (kWh/orang)',
#        'Pertumbuhan PDB (% Tahun)', 'Kepadatan_Penduduk'],
#       dtype='object')

# %%
df.head()
# Out:
#        Wilayah  Akses Jaringan Listrik (%)  Akses Bahan Bakar Bersih  \
# 0  Afghanistan                    1.613591                       6.2
# 1  Afghanistan                    4.074574                       7.2
# 2  Afghanistan                    9.409158                       8.2
# 3  Afghanistan                   14.738506                       9.5
# 4  Afghanistan                   20.064968                      10.9
#
#    Kapasitas Pembangkit Listrik Terbarukan per Kapita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
#    Listrik dari Bahan Bakar Fosil (TWh)  Listrik dari Energi Terbarukan (TWh)  \
# 0                                  0.16                                  0.31
# ...

# %%
#menampilkan jumlah row data kosong pada masing-maisng kolom
df.isna().sum()
# Out:
# Wilayah                                                 0
# Akses Jaringan Listrik (%)                             10
# Akses Bahan Bakar Bersih                              169
# Kapasitas Pembangkit Listrik Terbarukan per Kapita    931
# Listrik dari Bahan Bakar Fosil (TWh)                   21
# Listrik dari Energi Terbarukan (TWh)                   21
# Konsumsi Energi Primer per Kapita (kWh/orang)           0
# Pertumbuhan PDB (% Tahun)                             317
# Kepadatan_Penduduk                                      1
# dtype: int64

# %%
#visualisasi row data kosong pada masing masing kolom 
from jcopml.plot import plot_missing_value
plot_missing_value(df)

# %%
#Casting Type Data 
df['Kepadatan_Penduduk'] = df.Kepadatan_Penduduk.str.replace(',','').astype(float)

# %%
df.set_index('Wilayah', inplace = True)

# %%
#mengisi missing value denan nilai mean 
df.fillna(df.mean(), inplace =True)

# %%
df.isna().sum()
# Out:
# Akses Jaringan Listrik (%)                            0
# Akses Bahan Bakar Bersih                              0
# Kapasitas Pembangkit Listrik Terbarukan per Kapita    0
# Listrik dari Bahan Bakar Fosil (TWh)                  0
# Listrik dari Energi Terbarukan (TWh)                  0
# Konsumsi Energi Primer per Kapita (kWh/orang)         0
# Pertumbuhan PDB (% Tahun)                             0
# Kepadatan_Penduduk                                    0
# dtype: int64

# %%
#viasualisasi missing value
plot_missing_value(df)

# %%
#viasualisasi korelasi antar variabel dalam datasheet
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
plt.ioff()

# %%
#visualisasi garfik distribusi nilai kuantitatif pada masing-masing kolom
plt.figure(figsize=[20,12])

plt.subplot(241)
plt.boxplot(df['Akses Jaringan Listrik (%)'], showmeans = True, meanline = True)
plt.title('Akses Jaringan Listrik (%)')
plt.ylabel('Value')

plt.subplot(242)
plt.boxplot(df['Akses Bahan Bakar Bersih'], showmeans = True, meanline = True)
plt.title('Akses Bahan Bakar Bersih')
plt.ylabel('Value')

plt.subplot(243)
plt.boxplot(df['Kapasitas Pembangkit Listrik Terbarukan per Kapita'], showmeans = True, meanline = True)
plt.title('Kapasitas Pembangkit Listrik Terbarukan per Kapita')
plt.ylabel('Value')

plt.subplot(244)
plt.boxplot(df['Listrik dari Bahan Bakar Fosil (TWh)'], showmeans = True, meanline = True)
plt.title('Listrik dari Bahan Bakar Fosil (TWh)')
plt.ylabel('Value')

plt.subplot(245)
plt.boxplot(df['Listrik dari Energi Terbarukan (TWh)'], showmeans = True, meanline = True)
plt.title('Listrik dari Energi Terbarukan (TWh)')
plt.ylabel('Value')

plt.subplot(246)
plt.boxplot(df['Konsumsi Energi Primer per Kapita (kWh/orang)'], showmeans = True, meanline = True)
plt.title('Konsumsi Energi Primer per Kapita (kWh/orang)')
plt.ylabel('Value')

plt.subplot(247)
plt.boxplot(df['Pertumbuhan PDB (% Tahun)'], showmeans = True, meanline = True)
plt.title('Pertumbuhan PDB (% Tahun)')
plt.ylabel('Value')

plt.subplot(248)
plt.boxplot(df['Kepadatan_Penduduk'], showmeans = True, meanline = True)
plt.title('Kepadatan_Penduduk')
plt.ylabel('Value')

plt.show()

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#        Wilayah  Akses Jaringan Listrik (%)  Akses Bahan Bakar Bersih  \
# 0  Afghanistan                    1.613591                       6.2
# 1  Afghanistan                    4.074574                       7.2
# 2  Afghanistan                    9.409158                       8.2
# 3  Afghanistan                   14.738506                       9.5
# 4  Afghanistan                   20.064968                      10.9
#
#    Kapasitas Pembangkit Listrik Terbarukan per Kapita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
#    Listrik dari Bahan Bakar Fosil (TWh)  Listrik dari Energi Terbarukan (TWh)  \
# 0                                  0.16                                  0.31
# ...

# %%
#visualisasi wilayah dengan potensi renewable energy tertinggi
Rata_Rata_Potensi_Energi_Terbarukan_Berdasarkan_Negara= df.groupby('Wilayah')['Kapasitas Pembangkit Listrik Terbarukan per Kapita'].mean()

top_5_countries = Rata_Rata_Potensi_Energi_Terbarukan_Berdasarkan_Negara.nlargest(5)
plt.figure(figsize = (8, 4))
sns.barplot(x = top_5_countries.values, y = top_5_countries.index)
plt.xlabel('Kapasitas Pembangkit Listrik Terbarukan per Kapita')
plt.ylabel('Wilayah')
plt.title('5 Negara dengan Potensi Renewable Energi Tertinggi')

plt.xticks(rotation = 45, ha = 'center')

plt.tight_layout()
plt.show()

# %%
#visualisasi wilayah dengan potensi renewable energy terendah
Rata_Rata_Potensi_Energi_Terbarukan_Berdasarkan_Negara= df.groupby('Wilayah')['Kapasitas Pembangkit Listrik Terbarukan per Kapita'].mean()

top_5_countries = Rata_Rata_Potensi_Energi_Terbarukan_Berdasarkan_Negara.nsmallest(5)
plt.figure(figsize = (8, 4))
sns.barplot(x = top_5_countries.values, y = top_5_countries.index)
plt.xlabel('Jumlah Penggunaan Bahan Bakar Fosil (Twh)')
plt.ylabel('Wilayah')
plt.title('5 Negara dengan Potensi Renewable Energi Terendah')

plt.xticks(rotation = 45, ha = 'center')

plt.tight_layout()
plt.show()

# %%
#visualisasi wilayah dengan penggunaan bahan bakar fosil tertinggi
Rata_Rata_Potensi_Energi_Terbarukan_Berdasarkan_Negara= df.groupby('Wilayah')['Listrik dari Bahan Bakar Fosil (TWh)'].mean()

top_5_countries = Rata_Rata_Potensi_Energi_Terbarukan_Berdasarkan_Negara.nlargest(5)
plt.figure(figsize = (10, 6))
sns.barplot(x = top_5_countries.values, y = top_5_countries.index)
plt.xlabel('Jumlah Penggunaan Bahan Bakar Fosil (Twh)')
plt.ylabel('Wilayah')
plt.title('5 Negara dengan Penggunaan Listrik dari Bahan Bakar Fosil Tertinggi')

plt.xticks(rotation = 45, ha = 'center')

plt.tight_layout()
plt.show()

# %%
#visualisasi wilayah dengan pengunaan bahan bakar fosil terendah 
Rata_Rata_Potensi_Energi_Terbarukan_Berdasarkan_Negara= df.groupby('Wilayah')['Listrik dari Bahan Bakar Fosil (TWh)'].mean()

top_5_countries = Rata_Rata_Potensi_Energi_Terbarukan_Berdasarkan_Negara.nsmallest(5)
plt.figure(figsize = (10, 6))
sns.barplot(x = top_5_countries.values, y = top_5_countries.index)
plt.xlabel('Jumlah Penggunaan Bahan Bakar Fosil (Twh)')
plt.ylabel('Wilayah')
plt.title('5 Negara dengan Penggunaan Listrik dari Bahan Bakar Fosil Terendah')

plt.xticks(rotation = 45, ha = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pre-Modeling

# %%
#import library yang akan digunakan pada proses pre modeling
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Label Encoder untuk konversi data string ke numerik
LEncoder = LabelEncoder()

df['Wilayah'] = LEncoder.fit_transform(df['Wilayah'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 9 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Wilayah                                             3649 non-null   int32
#  1   Akses Jaringan Listrik (%)                          3649 non-null   float64
#  2   Akses Bahan Bakar Bersih                            3649 non-null   float64
#  3   Kapasitas Pembangkit Listrik Terbarukan per Kapita  3649 non-null   float64
#  4   Listrik dari Bahan Bakar Fosil (TWh)                3649 non-null   float64
#  5   Listrik dari Energi Terbarukan (TWh)                3649 non-null   float64
#  6   Konsumsi Energi Primer per Kapita (kWh/orang)       3649 non-null   float64
#  7   Pertumbuhan PDB (% Tahun)                           3649 non-null   float64
# ...

# %%
df['Wilayah']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 3644    175
# 3645    175
# 3646    175
# 3647    175
# 3648    175
# Name: Wilayah, Length: 3649, dtype: int32

# %%
#menentukan kolom untuk atribut(x) dan label(y)
X = df.drop('Wilayah',axis=1).values
y = df['Wilayah'].values

# %%
#split data testing dan data training dengan test size 0,4 
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.4, random_state=42)

# %%
#scaler data untuk memperkecil penyimpangan 
sc = StandardScaler()

X_train = sc.fit_transform(x_train)
X_test= sc.transform(x_test)

# %% [markdown]
# ## Modeling

# %%
# import library yang akan digunakan pada proses Modeling

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC

# %%
# training dan testing dengan Logistic Regression

logreg= LogisticRegression()

logreg.fit(X_train, y_train)

y_pred_logreg = logreg.predict(X_test)
# Out:
# C:\Users\Asani\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# training dan testing dengan Gradient Boosting Classifier


GB = GradientBoostingClassifier()

GB.fit(X_train, y_train)

y_pred_GB = GB.predict(X_test)

# %%
# training dan tetsing data dengan Random Forest Classifier

rf = RandomForestClassifier()

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

# %%
# training dan testing data dengan Decision Tree Classifier

dt = DecisionTreeClassifier()

dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

#Create plot size 10, 5
plt.figure(figsize=(15, 10))
plot_tree(dt, filled=True)
plt.title('Model Klasifier Decision Tree')
plt.show()

# %%
# training dan testing data dengan KNeighbors Classifier


knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

# %%
# training dan testing data dengan XGB Classifier

XGB = XGBClassifier() 

XGB.fit(X_train, y_train)

y_pred_XGB = XGB.predict(X_test)

# %%
import xgboost as xgb
xgb.plot_importance(XGB)
plt.show()

# %%
# training dan testing data dengan Support Vector classifier

svc = SVC(probability=True)

svc.fit(X_train,y_train)

y_pred_svc = svc.predict(X_test)

# %%
# menampilkan dimensi data training dan testing 
X_train.shape, y_train.shape,X_test.shape, y_test.shape
# Out:
# ((2189, 8), (2189,), (1460, 8), (1460,))

# %% [markdown]
# ## Evaluation

# %%
#import library yang akan digunakan pada proses evaluasi
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, recall_score, confusion_matrix, precision_recall_fscore_support
from sklearn.metrics import roc_auc_score,auc,f1_score
from sklearn.metrics import precision_recall_curve,roc_curve

# %%
#menmapilkan akurasi skor masing masing machine learning
models = []

Z = [SVC() , DecisionTreeClassifier() , LogisticRegression() , KNeighborsClassifier() ,XGBClassifier(),
    RandomForestClassifier() , GradientBoostingClassifier()]


X = ["SVC" , "DecisionTreeClassifier" , "LogisticRegression" , "KNeighborsClassifier" ,
    "RandomForestClassifier" , "GradientBoostingClassifier", "XGB"]

for i in range(0,len(Z)):
    model = Z[i]
    model.fit( X_train , y_train )
    pred = model.predict(X_test)
    models.append(accuracy_score(pred , y_test))
# Out:
# C:\Users\Asani\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
d = { "Accuracy" : models , "Algorithm" : X }
data_frame = pd.DataFrame(d)
data_frame
# Out:
#    Accuracy                   Algorithm
# 0  0.314384                         SVC
# 1  0.965753      DecisionTreeClassifier
# 2  0.473288          LogisticRegression
# 3  0.601370        KNeighborsClassifier
# 4  0.973973      RandomForestClassifier
# 5  0.995205  GradientBoostingClassifier
# 6  0.884932                         XGB

# %% [markdown]
# Model yang akan digunakan
# 1. Decision Tree
# 2. Random Forest
# 3. XGB

# %%
#evaluasi model Decision Tree
conf_matrix = confusion_matrix(y_test, y_pred_dt)
class_report = classification_report(y_test, y_pred_dt)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[ 4  0  0 ...  0  0  0]
#  [ 0  9  0 ...  0  0  0]
#  [ 0  0 11 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 11  0  0]
#  [ 0  0  0 ...  0  4  0]
#  [ 0  0  0 ...  0  0 10]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80         5
#            1       1.00      1.00      1.00         9
#            2       0.65      0.92      0.76        12
#            3       1.00      1.00      1.00         8
#            4       1.00      0.86      0.92         7
#            5       1.00      1.00      1.00         6
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         6
#            8       1.00      1.00      1.00        13
#            9       1.00      1.00      1.00         7
#           10       1.00      0.67      0.80        12
#           11       1.00      1.00      1.00        10
# ...

# %%
#evaluasi model Random forest
conf_matrix = confusion_matrix(y_test, y_pred_rf)
class_report = classification_report(y_test, y_pred_rf)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[ 5  0  0 ...  0  0  0]
#  [ 0  9  0 ...  0  0  0]
#  [ 0  0 12 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 11  0  0]
#  [ 0  0  0 ...  0  4  0]
#  [ 0  0  0 ...  0  0 10]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        12
#            3       1.00      1.00      1.00         8
#            4       1.00      1.00      1.00         7
#            5       1.00      1.00      1.00         6
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         6
#            8       1.00      1.00      1.00        13
#            9       1.00      1.00      1.00         7
#           10       1.00      1.00      1.00        12
#           11       1.00      1.00      1.00        10
# ...

# %%
#evaluasi model Xtreme gradient boosting
conf_matrix = confusion_matrix(y_test, y_pred_XGB)
class_report = classification_report(y_test, y_pred_XGB)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[ 5  0  0 ...  0  0  0]
#  [ 0  9  0 ...  0  0  0]
#  [ 0  0 12 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 11  0  0]
#  [ 0  0  0 ...  0  4  0]
#  [ 0  0  0 ...  0  0 10]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.90      1.00      0.95         9
#            2       1.00      1.00      1.00        12
#            3       1.00      1.00      1.00         8
#            4       1.00      1.00      1.00         7
#            5       1.00      1.00      1.00         6
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         6
#            8       1.00      1.00      1.00        13
#            9       1.00      0.86      0.92         7
#           10       1.00      1.00      1.00        12
#           11       1.00      1.00      1.00        10
# ...
