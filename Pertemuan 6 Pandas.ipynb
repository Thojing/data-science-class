# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
contoh = {'a':[1,2,3], 'b':[4,5,6], 'c':[7,8,9]}
contoh

# %%
pd.DataFrame(contoh)

# %% [markdown]
# ## Membaca File

# %%
df = pd.read_csv('Data/cereal.csv')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843

# %%
df.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 72   21.0     3.0    60.0   FDA_25      3     1.0  0.75  39.106174
# 73   13.0    12.0    25.0   FDA_25      2     1.0  1.00  27.753301
# 74   17.0     3.0   115.0   FDA_25      1     1.0  0.67  49.787445
# 75   17.0     3.0   110.0   FDA_25      1     1.0  1.00  51.592193
# 76   16.0     8.0    60.0   FDA_25      1     1.0  0.75  36.187559

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
df.shape
# Out:
# (77, 16)

# %%
df.mfr.head()
# Out:
# 0    N
# 1    Q
# 2    K
# 3    K
# 4    R
# Name: mfr, dtype: object

# %%
df['mfr'].head()
# Out:
# 0    N
# 1    Q
# 2    K
# 3    K
# 4    R
# Name: mfr, dtype: object

# %%
df[['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass']].head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass
# 0    5.0     6.0   280.0
# 1    8.0     8.0   135.0
# 2    7.0     5.0   320.0
# 3    8.0     0.0   330.0
# 4   14.0     8.0     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     76 non-null     float64
#  9   sugars    76 non-null     float64
#  10  potass    75 non-null     float64
#  11  vitamins  77 non-null     object
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(7), int64(5), object(4)
# memory usage: 9.8+ KB

# %%
df.mfr.value_counts()
# Out:
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %%
df[df.fat == 0]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 6                 Apple Jacks   K    C       110        2    0     125    1.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 15                  Corn Chex   R    C       110        2    0     280    0.0
# 16                Corn Flakes   K    C       100        2    0     290    1.0
# 17                  Corn Pops   K    C       110        1    0      90    1.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 21                    Crispix   K    C       110        2    0     220    1.0
# 23                Double Chex   R    C       100        2    0     190    1.0
# 25             Frosted Flakes   K    C       110        1    0     200    1.0
# 26        Frosted Mini-Wheats   K    C       100        3    0       0    3.0
# ...

# %% [markdown]
# ### Tugas 3
# Ulangi kodingan dari awal sampai akhir
# sekreatifnya dengan rapi
# dalam satu projek pertemuan lima (pengenalan python)
# dan pertemuan enam (numpy dan pandas)

# %%
df[df.fat>1]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 1                        100% Natural Bran   Q    C       120        3    5
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 7                                  Basic 4   G    C       130        3    2
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 11                                Cheerios   G    C       110        6    2
# 12                   Cinnamon Toast Crunch   G    C       120        1    3
# 13                                Clusters   G    C       110        3    2
# 19                      Cracklin' Oat Bran   K    C       110        3    3
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# 34                      Great Grains Pecan   P    C       120        3    3
# ...

# %%
df[(df.fat>1) & (df.vitamins == 'FDA_25')]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 7                                  Basic 4   G    C       130        3    2
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 11                                Cheerios   G    C       110        6    2
# 12                   Cinnamon Toast Crunch   G    C       120        1    3
# 13                                Clusters   G    C       110        3    2
# 19                      Cracklin' Oat Bran   K    C       110        3    3
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# 34                      Great Grains Pecan   P    C       120        3    3
# 35                        Honey Graham Ohs   Q    C       120        1    2
# ...

# %%
df[df.fat>1].head()
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 1         100% Natural Bran   Q    C       120        3    5      15    2.0
# 4            Almond Delight   R    C       110        2    2     200    1.0
# 5   Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 7                   Basic 4   G    C       130        3    2     210    2.0
# 10             Cap'n'Crunch   Q    C       120        1    2     220    0.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 1     8.0     8.0   135.0    FDA_0      3    1.00  1.00  33.983679
# 4    14.0     8.0     NaN   FDA_25      3    1.00  0.75  34.384843
# 5    10.5    10.0    70.0   FDA_25      1    1.00  0.75  29.509541
# 7    18.0     8.0   100.0   FDA_25      3    1.33  0.75  37.038562
# 10   12.0    12.0    35.0   FDA_25      2    1.00  0.75  18.042851

# %% [markdown]
# ## Missing Value

# %% [markdown]
# ### Impute/Mengatasi data yang kosong
# 1. Delete data
# 2. Isi data dengan mean, median, modus
# 3. Isi data dengan data sembarangan

# %%
df.isna().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       1
# sugars      1
# potass      2
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
#Menghapus data kosong
df.dropna()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
#Mengisi data kosong dengan rata-rata (mean)
df.fillna(df.mean()).head()
# Out:
# C:\Users\Asani\AppData\Local\Temp\ipykernel_1832\1854555140.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean()).head()
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars      potass vitamins  shelf  weight  cups     rating
# 0    5.0     6.0  280.000000   FDA_25      3     1.0  0.33  68.402973
# ...

# %%
#Mengisi data dengan nilai sembarangan
df.fillna('310.0').head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars potass vitamins  shelf  weight  cups     rating
# 0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973
# 1   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679
# 2   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505
# 3   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912
# 4  14.0    8.0  310.0   FDA_25      3     1.0  0.75  34.384843

# %%
#Mengisi data sembarangan lebih dari satu variabel
isi = {'carbo':10.0,'sugars':12.0,'potass':320.0}
df.fillna(isi).head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 4   14.0     8.0   320.0   FDA_25      3     1.0  0.75  34.384843

# %%
df.fillna(isi,inplace=True)
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.isna().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df.to_csv('Data/CerealEdit.csv')
